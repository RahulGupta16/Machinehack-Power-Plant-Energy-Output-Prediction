# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import *
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import xgboost as xgb
import lightgbm as lgb
import warnings
warnings.filterwarnings(action='ignore')

# %%
train = pd.read_csv(r'C:\Users\Rahul\Desktop\Machinehack-Power-Plant-Energy-Output-Prediction\Train.csv')
test = pd.read_csv(r'C:\Users\Rahul\Desktop\Machinehack-Power-Plant-Energy-Output-Prediction\Test.csv')
sample = pd.read_csv(r'C:\Users\Rahul\Desktop\Machinehack-Power-Plant-Energy-Output-Prediction\sample_submission.csv')

# %%
train.head()
# Out:
#       AT      V       AP     RH          PE
# 0  29.07  72.51  1009.24  58.38  449.371855
# 1  32.38  67.17  1006.97  60.04  450.861043
# 2  19.29  67.71  1007.94  63.71  460.894029
# 3  16.45  41.48  1016.64  45.21  467.577314
# 4  21.43  46.97  1013.94  61.25  469.805723

# %%
test.head()
# Out:
#       AT      V       AP     RH
# 0  16.98  53.16  1013.95  82.80
# 1   9.60  41.03  1021.01  69.03
# 2   6.11  38.68  1017.53  79.23
# 3  12.34  43.22  1009.28  78.23
# 4  27.67  59.14  1016.51  61.20

# %%
train.describe()
# Out:
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.723857    54.461361  1013.318927    73.165178   466.473971
# std       7.407995    12.679972     5.906082    14.618969    17.040831
# min       2.340000    25.360000   993.110000    25.890000   433.506276
# 25%      13.560000    41.780000  1009.210000    62.990000   451.893897
# 50%      20.550000    52.750000  1013.030000    74.855000   463.379534
# 75%      25.770000    66.560000  1017.342500    84.790000   480.565764
# max      37.110000    81.560000  1033.300000   100.160000   509.381540

# %%
test.describe()
# Out:
#                  AT             V            AP            RH
# count  38272.000000  38272.000000  38272.000000  38272.000000
# mean      19.633075     54.266914   1013.244116     73.344928
# std        7.463148     12.714068      5.946604     14.594796
# min        1.810000     25.360000    992.890000     25.560000
# 25%       13.500000     41.700000   1009.070000     63.390000
# 50%       20.300000     52.050000   1012.920000     74.990000
# 75%       25.710000     66.510000   1017.240000     84.840000
# max       37.110000     81.560000   1033.300000    100.160000

# %%
sns.distplot(train.PE)
train.PE.kurt(),train.PE.skew()
# Out:
# (-1.0331596996654575, 0.3222961114988882)

# %%
train.drop(train[train.PE<435].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### Feature by feature analysis

# %% [markdown]
# ### AT

# %%
sns.distplot(train.AT)

# %%
sns.distplot(test.AT)

# %%
#train['Farh']=(train.AT*1.8) + 32
#test['Farh']=(test.AT*1.8) + 32

# %%
sns.scatterplot(train.AT,train.PE)

# %% [markdown]
# ### V

# %%
sns.distplot(train.V)

# %%
sns.distplot(test.V)

# %%
train.V.min()
# Out:
# 25.36

# %%
sns.scatterplot(train.V,train.PE)

# %%
train.drop(index = train[train.V<30].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### AP

# %%
sns.distplot(train.AP)

# %%
sns.distplot(test.AP)

# %%
sns.scatterplot(train.AP,train.PE)

# %%
train.drop(index=train[train.AP<996].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### RH

# %%
sns.distplot(train.RH)

# %%
sns.distplot(test.RH)

# %%
sns.scatterplot(train.RH,train.PE)

# %%
train.drop(index=train[train.RH<28].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### Modelling

# %%
label = train['PE']
train.drop(columns=['PE'],inplace=True)

# %%
def model(m,train,label,test,splitters,rnd_st):
    prediction=pd.DataFrame(np.zeros(shape=(test.shape[0],splitters)))
    l1=[]
    l2=[]
    splitted = KFold(n_splits=splitters,random_state=rnd_st)
    
    for i,(tr_index,te_index) in enumerate(splitted.split(train,label)):
        x_train, x_test = train.loc[tr_index,:], train.loc[te_index,:]
        y_train,y_test = label[tr_index], label[te_index]
        
        m.fit(x_train,y_train)
        tr_pred = m.predict(x_train)
        te_pred = m.predict(x_test)
        
        l1.append(np.sqrt(mean_squared_error(y_train,tr_pred)))
        l2.append(np.sqrt(mean_squared_error(y_test,te_pred)))
        print('Training loss: {} \t\t\t\t Validation Loss {}'.format(np.sqrt(mean_squared_error(y_train,tr_pred)),np.sqrt(mean_squared_error(y_test,te_pred))))
        pd.Series(m.feature_importances_,index=train.columns).sort_values(ascending=True).plot.barh()
        prediction.iloc[:,i] = m.predict(test)
    
        
    print(np.mean(l1),np.mean(l2))
    return prediction

# %%
seed = 12435

# %%
final = model(ExtraTreesRegressor(n_estimators=500,random_state=seed),train,label,test,12,seed)
# Out:
# Training loss: 0.5437574795715503 				 Validation Loss 2.5046026038864584
# Training loss: 0.5404551703691621 				 Validation Loss 2.4532261624418767
# Training loss: 0.5477332458708443 				 Validation Loss 2.317886087811112
# Training loss: 0.5469153357438993 				 Validation Loss 2.9755007704927565
# Training loss: 0.5415860855009359 				 Validation Loss 2.6789156745734446
# Training loss: 0.5487790961636405 				 Validation Loss 2.66269375583831
# Training loss: 0.5452435090413833 				 Validation Loss 2.596432930531412
# Training loss: 0.5463232935595939 				 Validation Loss 2.507514568407095
# Training loss: 0.5420586697171261 				 Validation Loss 2.4295866121637513
# Training loss: 0.5442930373052158 				 Validation Loss 2.4111542459780586
# Training loss: 0.5479230390867763 				 Validation Loss 2.5119021409100295
# Training loss: 0.5427646298310825 				 Validation Loss 2.430508332030285
# 0.5448193826467675 2.5399936570887154

# %%
sample
# Out:
#                PE
# 0      472.459382
# 1      493.673699
# 2      496.046368
# 3      480.007971
# 4      445.407637
# 5      460.150348
# 6      457.110695
# 7      462.840941
# 8      473.409378
# 9      472.128067
# 10     475.486381
# 11     476.403990
# 12     460.856039
# 13     447.924443
# 14     487.753092
# 15     477.725451
# 16     449.642946
# 17     471.120361
# 18     447.407324
# 19     479.976269
# 20     456.250844
# 21     460.224509
# 22     493.220121
# 23     450.823702
# 24     459.958197
# 25     501.297832
# 26     455.792824
# 27     462.593849
# 28     469.898832
# 29     446.057439
# ...           ...
# 38242  477.670530
# 38243  447.302242
# 38244  467.240176
# 38245  477.818773
# 38246  457.674779
# 38247  480.522570
# 38248  455.090215
# 38249  488.403054
# 38250  456.638878
# 38251  452.949104
# 38252  462.653267
# 38253  472.406291
# 38254  500.016677
# 38255  463.417045
# 38256  501.244201
# 38257  483.801198
# 38258  482.226207
# 38259  448.165823
# 38260  452.199276
# 38261  481.512271
# 38262  446.507946
# 38263  478.356561
# 38264  485.506734
# 38265  490.742632
# 38266  497.527022
# 38267  475.604071
# 38268  447.174224
# 38269  472.656070
# 38270  447.162238
# 38271  463.783506
#
# [38272 rows x 1 columns]

# %%
pred = np.mean(final,axis=1)

# %%
sample['PE'] = pred

# %%
sample.to_csv('Base.csv',index=False)

# %%
sample
# Out:
#                PE
# 0      472.956508
# 1      494.858508
# 2      496.685062
# 3      480.749529
# 4      445.248894
# 5      460.175680
# 6      456.925343
# 7      462.862951
# 8      476.112852
# 9      473.173166
# 10     477.087038
# 11     478.850368
# 12     460.765601
# 13     446.553162
# 14     487.956637
# 15     478.130781
# 16     448.282768
# 17     473.151349
# 18     448.293865
# 19     480.052930
# 20     455.463904
# 21     460.016341
# 22     492.370267
# 23     448.790620
# 24     459.879808
# 25     503.553234
# 26     455.543928
# 27     463.191107
# 28     472.787824
# 29     446.076978
# ...           ...
# 38242  477.260832
# 38243  448.478707
# 38244  468.352336
# 38245  475.926936
# 38246  457.249575
# 38247  481.629589
# 38248  454.968398
# 38249  486.875751
# 38250  458.171633
# 38251  452.383416
# 38252  461.028827
# 38253  474.898703
# 38254  499.823361
# 38255  460.207956
# 38256  499.924735
# 38257  483.659831
# 38258  483.361737
# 38259  450.326846
# 38260  453.747416
# 38261  481.540785
# 38262  445.941663
# 38263  478.550406
# 38264  487.260172
# 38265  491.162125
# 38266  498.046471
# 38267  475.240146
# 38268  447.269977
# 38269  472.390715
# 38270  447.903675
# 38271  464.305984
#
# [38272 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import *
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import xgboost as xgb
import lightgbm as lgb
import warnings
warnings.filterwarnings(action='ignore')

# %%
train = pd.read_csv(r'C:\Users\Rahul\Desktop\Machinehack-Power-Plant-Energy-Output-Prediction\Train.csv')
test = pd.read_csv(r'C:\Users\Rahul\Desktop\Machinehack-Power-Plant-Energy-Output-Prediction\Test.csv')
sample = pd.read_csv(r'C:\Users\Rahul\Desktop\Machinehack-Power-Plant-Energy-Output-Prediction\sample_submission.csv')

# %%
train.head()
# Out:
#       AT      V       AP     RH          PE
# 0  29.07  72.51  1009.24  58.38  449.371855
# 1  32.38  67.17  1006.97  60.04  450.861043
# 2  19.29  67.71  1007.94  63.71  460.894029
# 3  16.45  41.48  1016.64  45.21  467.577314
# 4  21.43  46.97  1013.94  61.25  469.805723

# %%
test.head()
# Out:
#       AT      V       AP     RH
# 0  16.98  53.16  1013.95  82.80
# 1   9.60  41.03  1021.01  69.03
# 2   6.11  38.68  1017.53  79.23
# 3  12.34  43.22  1009.28  78.23
# 4  27.67  59.14  1016.51  61.20

# %%
train.describe()
# Out:
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.723857    54.461361  1013.318927    73.165178   466.473971
# std       7.407995    12.679972     5.906082    14.618969    17.040831
# min       2.340000    25.360000   993.110000    25.890000   433.506276
# 25%      13.560000    41.780000  1009.210000    62.990000   451.893897
# 50%      20.550000    52.750000  1013.030000    74.855000   463.379534
# 75%      25.770000    66.560000  1017.342500    84.790000   480.565764
# max      37.110000    81.560000  1033.300000   100.160000   509.381540

# %%
test.describe()
# Out:
#                  AT             V            AP            RH
# count  38272.000000  38272.000000  38272.000000  38272.000000
# mean      19.633075     54.266914   1013.244116     73.344928
# std        7.463148     12.714068      5.946604     14.594796
# min        1.810000     25.360000    992.890000     25.560000
# 25%       13.500000     41.700000   1009.070000     63.390000
# 50%       20.300000     52.050000   1012.920000     74.990000
# 75%       25.710000     66.510000   1017.240000     84.840000
# max       37.110000     81.560000   1033.300000    100.160000

# %%
sns.distplot(train.PE)
train.PE.kurt(),train.PE.skew()
# Out:
# (-1.0331596996654575, 0.3222961114988882)

# %%
train.drop(train[train.PE<435].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### Feature by feature analysis

# %% [markdown]
# ### AT

# %%
sns.distplot(train.AT)

# %%
sns.distplot(test.AT)

# %%
sns.scatterplot(train.AT,train.PE)

# %% [markdown]
# train.drop(index=train[train.AT>37].index,inplace=True)
# train.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### V

# %%
sns.distplot(train.V)

# %%
sns.distplot(test.V)

# %%
sns.scatterplot(train.V,train.PE)

# %% [markdown]
# train.drop(index = train[train.V<30].index,inplace=True)
# train.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### AP

# %%
sns.distplot(train.AP)

# %%
sns.distplot(test.AP)

# %%
sns.scatterplot(train.AP,train.PE)

# %% [markdown]
# train['Pres_dif']=pd.DataFrame(train.AP - train.AP.shift(1))
# test['Pres_dif']=pd.DataFrame(test.AP - test.AP.shift(1))
# train['Pres_dif']=train['Pres_dif'].fillna(0)
# test['Pres_dif']=test['Pres_dif'].fillna(0)

# %% [markdown]
# train.drop(index=train[train.AP<996].index,inplace=True)
# train.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### RH

# %%
sns.distplot(train.RH)

# %%
sns.distplot(test.RH)

# %%
train.RH=train.RH/100
test.RH=test.RH/100

# %%
sns.scatterplot(train.RH,train.PE)

# %% [markdown]
# train.drop(index=train[train.RH<30].index,inplace=True)
# train.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### Combined

# %% [markdown]
# ### Modelling

# %%
label = train['PE']
train.drop(columns=['PE'],inplace=True)
#test.drop(columns=['PE'],inplace=True)

# %%
def model(m,train,label,test,splitters,rnd_st):
    prediction=pd.DataFrame(np.zeros(shape=(test.shape[0],splitters)))
    l1=[]
    l2=[]
    splitted = KFold(n_splits=splitters,random_state=rnd_st)
    
    for i,(tr_index,te_index) in enumerate(splitted.split(train,label)):
        x_train, x_test = train.loc[tr_index,:], train.loc[te_index,:]
        y_train,y_test = label[tr_index], label[te_index]
        
        m.fit(x_train,y_train)
        tr_pred = m.predict(x_train)
        te_pred = m.predict(x_test)
        
        l1.append(np.sqrt(mean_squared_error(y_train,tr_pred)))
        l2.append(np.sqrt(mean_squared_error(y_test,te_pred)))
        print('Training loss: {} \t\t\t\t Validation Loss {}'.format(np.sqrt(mean_squared_error(y_train,tr_pred)),np.sqrt(mean_squared_error(y_test,te_pred))))
    #    pd.Series(m.feature_importances_,index=train.columns).sort_values(ascending=True).plot.barh()
        
        prediction.iloc[:,i] = m.predict(test)
    
        
    print(np.mean(l1),np.mean(l2))
    return prediction

# %%
seed = 78040

# %%
final = model(lgb.LGBMRegressor(random_state=seed,n_estimators=5000),train,label,test,21,seed)
# Out:
# Training loss: 0.6276516930911317 				 Validation Loss 2.253391602128458
# Training loss: 0.6156677589920966 				 Validation Loss 2.3688544134703347
# Training loss: 0.6241369809881654 				 Validation Loss 2.3912296470174548
# Training loss: 0.6172268388943151 				 Validation Loss 2.523907156020751
# Training loss: 0.6122238177742927 				 Validation Loss 2.171065662151273
# Training loss: 0.6182433823267512 				 Validation Loss 3.134450963924169
# Training loss: 0.6167336744475314 				 Validation Loss 2.6429955349232683
# Training loss: 0.6108845508907879 				 Validation Loss 2.7902309629586846
# Training loss: 0.6067654323494859 				 Validation Loss 2.417325363889187
# Training loss: 0.6188629860807157 				 Validation Loss 2.5550655681400367
# Training loss: 0.6141449613044193 				 Validation Loss 2.849377779102058
# Training loss: 0.6120487609103241 				 Validation Loss 2.3057729285616015
# Training loss: 0.6293454943775318 				 Validation Loss 2.1882469253765007
# Training loss: 0.614820915069373 				 Validation Loss 2.4859798086347116
# Training loss: 0.6138776286787007 				 Validation Loss 2.064457247138354
# Training loss: 0.6158637745571173 				 Validation Loss 2.3253254727350874
# Training loss: 0.6186485257891633 				 Validation Loss 2.124112647871895
# Training loss: 0.6078108932616677 				 Validation Loss 2.52888812933857
# Training loss: 0.6159468961496116 				 Validation Loss 2.369123067452749
# Training loss: 0.6279908955703342 				 Validation Loss 2.3174339141745977
# Training loss: 0.6098275170785423 				 Validation Loss 2.1798559749538655
# 0.6166058751705743 2.4279567033316005

# %%
pred = np.mean(final,axis=1)

# %%
sample['PE'] = pred

# %%
sample.to_csv('lgb2.csv',index=False)

# %%
sample
# Out:
#                PE
# 0      470.678113
# 1      495.117441
# 2      495.228605
# 3      479.885362
# 4      445.361984
# 5      460.778667
# 6      455.452393
# 7      462.839283
# 8      476.060758
# 9      473.642167
# 10     478.851984
# 11     478.799315
# 12     460.830495
# 13     447.130332
# 14     488.006609
# 15     475.920182
# 16     448.266632
# 17     469.614333
# 18     448.337690
# 19     479.911048
# 20     456.103298
# 21     460.020876
# 22     492.421194
# 23     448.888618
# 24     459.867073
# 25     503.947643
# 26     455.404644
# 27     463.180656
# 28     472.610436
# 29     446.154820
# ...           ...
# 38242  478.274906
# 38243  451.552770
# 38244  467.430335
# 38245  477.342628
# 38246  457.331160
# 38247  478.373117
# 38248  455.417466
# 38249  486.674943
# 38250  457.222856
# 38251  452.260991
# 38252  461.056610
# 38253  474.647800
# 38254  499.895417
# 38255  459.889599
# 38256  499.838101
# 38257  483.721761
# 38258  482.783292
# 38259  450.618701
# 38260  453.346089
# 38261  481.506724
# 38262  445.945342
# 38263  478.545022
# 38264  488.015323
# 38265  491.304709
# 38266  498.111694
# 38267  475.587642
# 38268  447.351254
# 38269  472.608011
# 38270  445.342708
# 38271  464.623896
#
# [38272 rows x 1 columns]
